# %%
"""
THIS IS FOR GETTING THE FINANCIAL DATA
"""
import yfinance as yf


asset_class = ["BIL", "GLD", "SPY","TLT"]

data = yf.download(asset_class, start = "2005-01-01", auto_adjust = True)
price_data = data["Close"]

price_datas = price_data.to_csv("asset_prices_new.csv")
# Out:
# [*********************100%***********************]  4 of 4 completed
